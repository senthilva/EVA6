# %%
# !git clone https://github.com/senthilva/YoloV3-1
# Out:
# Cloning into 'YoloV3-1'...
# remote: Enumerating objects: 202, done.
# remote: Counting objects: 100% (42/42), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 202 (delta 24), reused 0 (delta 0), pack-reused 160
# Receiving objects: 100% (202/202), 12.79 MiB | 25.19 MiB/s, done.
# Resolving deltas: 100% (32/32), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.9.0+cu102 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15109MB, multi_processor_count=40)

# %%
ls
# Out:
# drive/  sample_data/  YoloV3-1/

# %%
cd YoloV3-1
# Out:
# /content/YoloV3-1

# %%
# !python train.py --weights '/content/drive/MyDrive/py_stuff/customdata/yolov3-spp-ultralytics.pt' --data data/smalcoco/smalcoco.data --batch 3 --cache --epochs 3 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=3, bucket='', cache_images=True, cfg='cfg/yolov3-spp.cfg', data='data/smalcoco/smalcoco.data', device='', epochs=3, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='/content/drive/MyDrive/py_stuff/customdata/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15109MB)
#
# 2021-07-31 11:14:52.372047: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# Model Summary: 225 layers, 6.29987e+07 parameters, 6.29987e+07 gradients
# ...

# %%
# !python train.py --data data/customdata/custom.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 3 --nosave --weights '/content/drive/MyDrive/py_stuff/customdata/yolov3-spp-ultralytics.pt'
# Out:
# Namespace(accumulate=4, adam=False, batch_size=10, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=3, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='/content/drive/MyDrive/py_stuff/customdata/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15109MB)
#
# 2021-07-31 11:22:31.521750: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# ...

# %%
# !python train.py --data data/customdata/custom.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 30 --nosave --weights '/content/drive/MyDrive/py_stuff/customdata/yolov3-spp-ultralytics.pt'
# Out:
# Namespace(accumulate=4, adam=False, batch_size=10, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=30, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='/content/drive/MyDrive/py_stuff/customdata/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15109MB)
#
# 2021-07-31 12:51:46.502636: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# ...

# %%
# !python detect.py --source '/content/drive/MyDrive/py_stuff/customdata/viddata' --conf-thres 0.1 --output '/content/drive/MyDrive/py_stuff/customdata/viddata/out'
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='/content/drive/MyDrive/py_stuff/customdata/viddata/out', save_txt=False, source='/content/drive/MyDrive/py_stuff/customdata/viddata', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15109MB)
#
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# ...

# %%
# !python detect.py --source '/content/drive/MyDrive/py_stuff/customdata/testdata' --conf-thres 0.1 --output '/content/drive/MyDrive/py_stuff/customdata/testdata/out'
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='/content/drive/MyDrive/py_stuff/customdata/testdata/out', save_txt=False, source='/content/drive/MyDrive/py_stuff/customdata/testdata', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15109MB)
#
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# ...

# %%
Image(filename='/content/drive/MyDrive/py_stuff/customdata/testdata/out/b1.jpg', width=300)

# %%
Image(filename='/content/drive/MyDrive/py_stuff/customdata/testdata/out/b2.jpg', width=300)

# %%
Image(filename='/content/drive/MyDrive/py_stuff/customdata/testdata/out/b3.jpg', width=300)

# %%
Image(filename='/content/drive/MyDrive/py_stuff/customdata/testdata/out/b4.jpg', width=300)

# %%
Image(filename='/content/drive/MyDrive/py_stuff/customdata/testdata/out/m1.jpg', width=300)

# %%
Image(filename='/content/drive/MyDrive/py_stuff/customdata/testdata/out/m2.jpg', width=300)

# %%
Image(filename='/content/drive/MyDrive/py_stuff/customdata/testdata/out/m3.jpg', width=300)

# %%
Image(filename='/content/drive/MyDrive/py_stuff/customdata/testdata/out/m4.jpg', width=300)

# %%
Image(filename='/content/drive/MyDrive/py_stuff/customdata/testdata/out/hh1.jpg', width=300)

# %%
Image(filename='/content/drive/MyDrive/py_stuff/customdata/testdata/out/hh3.jpg', width=300)

# %%
Image(filename='/content/drive/MyDrive/py_stuff/customdata/testdata/out/hh4.jpg', width=300)

# %%
Image(filename='/content/drive/MyDrive/py_stuff/customdata/testdata/out/v1.jpg', width=300)

# %%
Image(filename='/content/drive/MyDrive/py_stuff/customdata/testdata/out/v2.jpg', width=300)

# %%
Image(filename='/content/drive/MyDrive/py_stuff/customdata/testdata/out/v3.jpg', width=300)

# %%
Image(filename='/content/drive/MyDrive/py_stuff/customdata/testdata/out/v4.jpg', width=300)
